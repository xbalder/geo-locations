# %%
import os
import pandas as pd
import seaborn as sns
from pathlib import Path
import numpy as np

def set_correct_working_dir(working_dir: str):
    current_working_dir = Path(os.getcwd())
    if working_dir == current_working_dir.name:
        print('WD correct')
        return
    for directory in current_working_dir.parents:
        if working_dir == directory.name:
            os.chdir(str(directory.absolute()))
            print('New WD:', str(directory.absolute()))
            return
    raise FileNotFoundError

set_correct_working_dir('geo-locations')
# Out:
# New WD: C:\Users\vzagolla\Documents\GitHub\geo-locations

# %%
dir_path = Path(os.getcwd()) / 'data' / 'general' / 'country_codes' 
source = dir_path / 'country-codes_csv.csv'
country_codes_df = pd.read_csv(source)
display(country_codes_df.head())
# Out:
#   official_name_ar official_name_cn official_name_en official_name_es  \
# 0              NaN              NaN              NaN              NaN
# 1        أفغانستان              阿富汗      Afghanistan       Afganistán
# 2          ألبانيا            阿尔巴尼亚          Albania          Albania
# 3          الجزائر            阿尔及利亚          Algeria          Argelia
# 4  ساموا الأمريكية            美属萨摩亚   American Samoa  Samoa Americana
#
#     official_name_fr    official_name_ru ISO3166-1-Alpha-2 ISO3166-1-Alpha-3  \
# 0                NaN                 NaN                TW               TWN
# 1        Afghanistan          Афганистан                AF               AFG
# 2            Albanie             Албания                AL               ALB
# 3            Algérie               Алжир                DZ               DZA
# 4  Samoa américaines  Американское Самоа                AS               ASM
#
#    ISO3166-1-numeric ISO4217-currency_alphabetic_code  ...  \
# 0              158.0                              NaN  ...
# 1                4.0                              AFN  ...
# 2                8.0                              ALL  ...
# 3               12.0                              DZD  ...
# 4               16.0                              USD  ...
#
#   Least Developed Countries (LDC) MARC Region Code Region Name  \
# 0                             NaN   ch         NaN         NaN
# 1                               x   af       142.0        Asia
# 2                             NaN   aa       150.0      Europe
# 3                             NaN   ae         2.0      Africa
# 4                             NaN   as         9.0     Oceania
#
#    Small Island Developing States (SIDS) Sub-region Code  Sub-region Name  \
# 0                                    NaN             NaN              NaN
# 1                                    NaN            34.0    Southern Asia
# 2                                    NaN            39.0  Southern Europe
# 3                                    NaN            15.0  Northern Africa
# 4                                      x            61.0        Polynesia
#
#    TLD  WMO   is_independent
# 0  .tw  NaN              Yes
# 1  .af   AF              Yes
# 2  .al   AB              Yes
# 3  .dz   AL              Yes
# 4  .as  NaN  Territory of US
#
# [5 rows x 56 columns]
