# %%
import os
import pandas as pd
import seaborn as sns
from pathlib import Path
import numpy as np

def set_correct_working_dir(working_dir: str):
    current_working_dir = Path(os.getcwd())
    if working_dir == current_working_dir.name:
        print('WD correct')
        return
    for directory in current_working_dir.parents:
        if working_dir == directory.name:
            os.chdir(str(directory.absolute()))
            print('New WD:', str(directory.absolute()))
            return
    raise FileNotFoundError

set_correct_working_dir('geo-locations')
# Out:
# WD correct

# %% [markdown]
# ### Reading in data

# %%
country_code = 'ind'
source = 'geonames'
country_path = Path(os.getcwd()) / 'data' / country_code
source = country_path / '_'.join(['source', source]) / 'IN.txt'
# column description to be found at: https://download.geonames.org/export/zip/
geonames_df = pd.read_csv(source, sep='\t', names=['country_code ', 'postal_code', 'place_name', 'admin_name_1', 'admin_code_1', 'admin_name_2', 'admin_code_2', 'admin_name_3', 'admin_code_3', 'latitude', 'longitude', 'accuracy'], converters={'postal_code': str})
display(geonames_df.head())
# Out:
#   country_code  postal_code    place_name               admin_name_1  \
# 0            IN      744101  Marine Jetty  Andaman & Nicobar Islands
# 1            IN      744101    Port Blair  Andaman & Nicobar Islands
# 2            IN      744101  N.S.Building  Andaman & Nicobar Islands
# 3            IN      744102         Haddo  Andaman & Nicobar Islands
# 4            IN      744102       Chatham  Andaman & Nicobar Islands
#
#    admin_code_1   admin_name_2  admin_code_2 admin_name_3  admin_code_3  \
# 0             1  South Andaman           NaN    Portblair           NaN
# 1             1  South Andaman           NaN   Port Blair           NaN
# 2             1  South Andaman           NaN    Portblair           NaN
# 3             1  South Andaman           NaN   Port Blair           NaN
# 4             1  South Andaman           NaN    Portblair           NaN
#
#    latitude  longitude  accuracy
# 0   11.6667    92.7500         3
# 1   11.6667    92.7500         4
# 2   11.6667    92.7500         3
# 3   11.6833    92.7167         4
# 4   11.7000    92.6667         3

# %%
try:
    geonames_df.drop(columns=['admin_code_1', 'admin_code_2', 'admin_code_3', 'accuracy'], inplace=True)
except KeyError:
    pass
geonames_df.fillna(np.NaN)
for str_col in ['admin_name_1', 'admin_name_2', 'admin_name_3', 'place_name']:
    geonames_df.loc[(geonames_df[str_col].isnull(), 'admin_name_3')] = ''  # empty string for string columns

geonames_df.loc[(geonames_df['admin_name_2'] == geonames_df['admin_name_3'], 'admin_name_3')] = ''

geonames_df = geonames_df.groupby('postal_code').agg({'admin_name_1': lambda col: ';'.join(col),
                                                      'admin_name_2': lambda col: ';'.join(col),
                                                      'admin_name_3': lambda col: ';'.join(col), 
                                                      'place_name': lambda col: '||'.join(col),
                                                      'latitude': 'mean',
                                                      'longitude': 'mean'}).reset_index()

geonames_df['admin_name_1'] = geonames_df['admin_name_1'].apply(lambda x: ';'.join(list(set([y for y in x.split(';') if y]))) if ';' in x else x)
geonames_df['admin_name_2'] = geonames_df['admin_name_2'].apply(lambda x: ';'.join(list(set([y for y in x.split(';') if y]))) if ';' in x else x)
geonames_df['admin_name_3'] = geonames_df['admin_name_3'].apply(lambda x: ';'.join(list(set([y for y in x.split(';') if y]))) if ';' in x else x)
geonames_df.loc[(geonames_df['admin_name_3'] == '', 'region_id')] = geonames_df['admin_name_1'] + '::' + geonames_df['admin_name_2'] + '::' + geonames_df['place_name']
geonames_df.loc[(geonames_df['admin_name_3'] != '', 'region_id')] = geonames_df['admin_name_1'] + '::' + geonames_df['admin_name_2'] + '::' + geonames_df['admin_name_3'] + '::' + geonames_df['place_name']
geonames_df.reset_index(inplace=True, drop=True)
geonames_df.sort_values('postal_code', inplace=True)
geonames_df.insert(loc=0, column='country_code', value=country_code)
geonames_df = geonames_df.round({'latitude': 4, 'longitude': 4})
display(geonames_df.head(50))
# Out:
#    country_code postal_code admin_name_1                 admin_name_2  \
# 0           ind      110001        Delhi      New Delhi;Central Delhi
# 1           ind      110002        Delhi                Central Delhi
# 2           ind      110003        Delhi    South Delhi;Central Delhi
# 3           ind      110004        Delhi                Central Delhi
# 4           ind      110005        Delhi                Central Delhi
# 5           ind      110006        Delhi    North Delhi;Central Delhi
# 6           ind      110007        Delhi                  North Delhi
# 7           ind      110008        Delhi                Central Delhi
# 8           ind      110009        Delhi             North West Delhi
# 9           ind      110010        Delhi             South West Delhi
# 10          ind      110011        Delhi                Central Delhi
# 11          ind      110012        Delhi                Central Delhi
# 12          ind      110013        Delhi                  South Delhi
# 13          ind      110014        Delhi                  South Delhi
# 14          ind      110015        Delhi                   West Delhi
# 15          ind      110016        Delhi             South West Delhi
# 16          ind      110017        Delhi                  South Delhi
# 17          ind      110018        Delhi                   West Delhi
# 18          ind      110019        Delhi                  South Delhi
# 19          ind      110020        Delhi        New Delhi;South Delhi
# 20          ind      110021        Delhi             South West Delhi
# 21          ind      110022        Delhi             South West Delhi
# 22          ind      110023        Delhi             South West Delhi
# 23          ind      110024        Delhi                  South Delhi
# 24          ind      110025        Delhi                  South Delhi
# 25          ind      110026        Delhi                   West Delhi
# 26          ind      110027        Delhi                   West Delhi
# 27          ind      110028        Delhi             South West Delhi
# 28          ind      110029        Delhi   New Delhi;South West Delhi
# 29          ind      110030        Delhi             South West Delhi
# 30          ind      110031        Delhi                   East Delhi
# 31          ind      110032        Delhi  East Delhi;North East Delhi
# 32          ind      110033        Delhi             North West Delhi
# 33          ind      110034        Delhi             North West Delhi
# 34          ind      110035        Delhi             North West Delhi
# 35          ind      110036        Delhi             North West Delhi
# 36          ind      110037        Delhi             South West Delhi
# 37          ind      110038        Delhi             South West Delhi
# 38          ind      110039        Delhi             North West Delhi
# 39          ind      110040        Delhi             North West Delhi
# 40          ind      110041        Delhi                   West Delhi
# 41          ind      110042        Delhi             North West Delhi
# 42          ind      110043        Delhi             South West Delhi
# 43          ind      110044        Delhi                  South Delhi
# 44          ind      110045        Delhi             South West Delhi
# 45          ind      110046        Delhi             South West Delhi
# 46          ind      110047        Delhi             South West Delhi
# 47          ind      110048        Delhi                  South Delhi
# 48          ind      110049        Delhi                  South Delhi
# 49          ind      110051        Delhi                   East Delhi
#
#        admin_name_3                                         place_name  \
# 0         New Delhi  Connaught Place||North Avenue||New Delhi G.P.O...
# 1         New Delhi  Indraprastha||A.G.C.R.||Darya Ganj||Minto Road...
# 2   New Delhi;Delhi  C G O Complex||Kasturba Nagar (South Delhi)||D...
# 3         New Delhi                                 Rashtrapati Bhawan
# 4         New Delhi  Bank Street (Central Delhi)||Guru Gobind Singh...
# 5             Delhi  Delhi G.P.O.||Jama Masjid||Chawri Bazar||Chand...
# 6             Delhi  C.C.I.||Jawahar Nagar (North Delhi)||Kamla Nag...
# 7         New Delhi  Dada Ghosh Bhawan||Patel Nagar West||Patel Nag...
# 8             Delhi  Model Town II||Model Town III||Gujranwala Colo...
# 9                    505 A B Workshop||COD (South West Delhi)||Dhau...
# 10        New Delhi          Nirman Bhawan||South Avenue||Udyog Bhawan
# 11        New Delhi  I.A.R.I.||National Physical Laboratory||Inderpuri
# 12        New Delhi                   Hazrat Nizamuddin||Dargah Sharif
# 13        New Delhi  Jungpura||Jeevan Nagar||Hari Nagar Ashram||Pra...
# 14        New Delhi  ESI||Delhi Industrial Area||L. M. Nagar Indl. ...
# 15                   Hauz Khas Market||Hauz Khas||Green Park Market...
# 16        New Delhi  Malviya Nagar (South Delhi)||Distt. Court Comp...
# 17        New Delhi  Vishnu Garden||Chaukhandi||Khyala Phase -  I||...
# 18        New Delhi  Nehru Place||Ali||Chittranjan Park||Kalkaji||T...
# 19        New Delhi  Okhla Industrial Estate||F F C Okhla||Okhla In...
# 20                   Anand Niketan||Nanak Pura||Moti Bagh||Malcha M...
# 21                   R K Puram Sect-8||R K Puram Sect7||R K Puram S...
# 22            Delhi  Kidwai Nagar East||Nauroji Nagar||Laxmi Bai Na...
# 23        New Delhi  Amar Colony||Lajpat Nagar (South Delhi)||Defen...
# 24        New Delhi  Sukhdev Vihar||New Friends Colony||Jamia Nagar...
# 25        New Delhi  Shivaji Park (West Delhi)||Ashoka Park Extn.||...
# 26        New Delhi  Subhash Nagar (West Delhi)||Tagore Garden||Sub...
# 27        New Delhi  Naraina Village||Kair||Naraina Industrial Esta...
# 28                     Safdarjung Enclave||Nauroji Nagar||Ansari Nagar
# 29                   Mehrauli||T B Hospital||Sultanpur||Lado Sarai|...
# 30                   Gandhi Nagar Bazar||Shastri Nagar (East Delhi)...
# 31                   Shahdara||Babarpur (North East Delhi)||Bhola N...
# 32            Delhi  Jahangir Puri A Block||Adrash Nagar||Bhalaswa|...
# 33            Delhi  Anandvas Shakurpur||Saraswati Vihar||Sri Nagar...
# 34            Delhi  Keshav Puram (North West Delhi)||Rampura||Onka...
# 35            Delhi  Alipur||Kadipur||Bakhtawar Pur||Palla||Bakoli|...
# 36                   Mahipalpur||Samalkha||Gurgaon Road||Palam Airp...
# 37                                              A F Rajokari||Rajokari
# 38            Delhi  Ghoga||Jat Khore||Bawana||Auchandi||Barwala||H...
# 39            Delhi  Kanya Gurukul||Narela||Singhu||Lampur||Bankner...
# 40        New Delhi  Nilothi||Mundka||Tikri Kalan||Bakkarwala||Ranh...
# 41            Delhi  Pehlad Pur||Samai Pur||Siraspur||Delhi Engg. C...
# 42        New Delhi  Tilangpur Kotla||Daulatpur||Dindarpur||Najafga...
# 43        New Delhi  Jaitpur||Badarpur (South Delhi)||Tugalkabad Ra...
# 44        New Delhi        Nasirpur||Indira Park||Dabri||Palam Village
# 45        New Delhi                              Nangal Raya||Sagarpur
# 46                               Mandi||Aya Nagar||Jaunapur||Arjungarh
# 47        New Delhi       Kailash Colony||Greater Kailash||Masjid Moth
# 48        New Delhi  Gulmohar Park||Sadiq Nagar||New Delhi South Ex...
# 49                   Krishna Nagar||Govind Pura||Ram Nagar (East De...
#
#     latitude  longitude                                          region_id
# 0    28.6371    77.2162  Delhi::New Delhi;Central Delhi::New Delhi::Con...
# 1    28.5635    77.2717  Delhi::Central Delhi::New Delhi::Indraprastha|...
# 2    28.6105    77.2329  Delhi::South Delhi;Central Delhi::New Delhi;De...
# 3    28.6105    77.2329  Delhi::Central Delhi::New Delhi::Rashtrapati B...
# 4    28.6516    77.1886  Delhi::Central Delhi::New Delhi::Bank Street (...
# 5    28.6105    77.2329  Delhi::North Delhi;Central Delhi::Delhi::Delhi...
# 6    28.6105    77.2329  Delhi::North Delhi::Delhi::C.C.I.||Jawahar Nag...
# 7    28.6105    77.2329  Delhi::Central Delhi::New Delhi::Dada Ghosh Bh...
# 8    28.6105    77.2329  Delhi::North West Delhi::Delhi::Model Town II|...
# 9    28.8047    77.6823  Delhi::South West Delhi::505 A B Workshop||COD...
# 10   28.8047    77.6823  Delhi::Central Delhi::New Delhi::Nirman Bhawan...
# 11   28.8047    77.6823  Delhi::Central Delhi::New Delhi::I.A.R.I.||Nat...
# 12   28.8047    77.6823  Delhi::South Delhi::New Delhi::Hazrat Nizamudd...
# 13   28.8047    77.6823  Delhi::South Delhi::New Delhi::Jungpura||Jeeva...
# 14   28.5345    77.2779  Delhi::West Delhi::New Delhi::ESI||Delhi Indus...
# 15   28.5531    77.1916  Delhi::South West Delhi::Hauz Khas Market||Hau...
# 16   28.8047    77.6823  Delhi::South Delhi::New Delhi::Malviya Nagar (...
# 17   25.4167    81.8500  Delhi::West Delhi::New Delhi::Vishnu Garden||C...
# 18   30.7597    76.0459  Delhi::South Delhi::New Delhi::Nehru Place||Al...
# 19   28.5345    77.2779  Delhi::New Delhi;South Delhi::New Delhi::Okhla...
# 20   28.5796    77.0907  Delhi::South West Delhi::Anand Niketan||Nanak ...
# 21   28.5796    77.0907  Delhi::South West Delhi::R K Puram Sect-8||R K...
# 22   28.5796    77.0907  Delhi::South West Delhi::Delhi::Kidwai Nagar E...
# 23   28.5796    77.0907  Delhi::South Delhi::New Delhi::Amar Colony||La...
# 24   28.5796    77.0907  Delhi::South Delhi::New Delhi::Sukhdev Vihar||...
# 25   28.5796    77.0907  Delhi::West Delhi::New Delhi::Shivaji Park (We...
# 26   28.5796    77.0907  Delhi::West Delhi::New Delhi::Subhash Nagar (W...
# 27   28.6094    76.9439  Delhi::South West Delhi::New Delhi::Naraina Vi...
# 28   28.5650    77.1972  Delhi::New Delhi;South West Delhi::Safdarjung ...
# 29   28.1758    78.1064  Delhi::South West Delhi::Mehrauli||T B Hospita...
# 30   27.7372    79.1863  Delhi::East Delhi::Gandhi Nagar Bazar||Shastri...
# 31   28.6679    77.2983  Delhi::East Delhi;North East Delhi::Shahdara||...
# 32   27.7372    79.1863  Delhi::North West Delhi::Delhi::Jahangir Puri ...
# 33   27.7372    79.1863  Delhi::North West Delhi::Delhi::Anandvas Shaku...
# 34   26.9175    79.1940  Delhi::North West Delhi::Delhi::Keshav Puram (...
# 35   26.7109    80.4249  Delhi::North West Delhi::Delhi::Alipur||Kadipu...
# 36   28.5392    77.1087  Delhi::South West Delhi::Mahipalpur||Samalkha|...
# 37   27.7372    79.1863    Delhi::South West Delhi::A F Rajokari||Rajokari
# 38   28.1729    80.6768  Delhi::North West Delhi::Delhi::Ghoga||Jat Kho...
# 39   28.8531    77.0873  Delhi::North West Delhi::Delhi::Kanya Gurukul|...
# 40   28.1530    77.8736  Delhi::West Delhi::New Delhi::Nilothi||Mundka|...
# 41   27.9204    78.1458  Delhi::North West Delhi::Delhi::Pehlad Pur||Sa...
# 42   28.2549    77.5504  Delhi::South West Delhi::New Delhi::Tilangpur ...
# 43   27.5799    79.5100  Delhi::South Delhi::New Delhi::Jaitpur||Badarp...
# 44   27.5021    77.2913  Delhi::South West Delhi::New Delhi::Nasirpur||...
# 45   24.6451    85.0242  Delhi::South West Delhi::New Delhi::Nangal Ray...
# 46   28.7806    76.7726  Delhi::South West Delhi::Mandi||Aya Nagar||Jau...
# 47   28.5434    77.2422  Delhi::South Delhi::New Delhi::Kailash Colony|...
# 48   27.9204    78.1458  Delhi::South Delhi::New Delhi::Gulmohar Park||...
# 49   28.3256    76.5918  Delhi::East Delhi::Krishna Nagar||Govind Pura|...

# %%
try:
    geonames_df.drop(columns=['admin_name_1', 'admin_name_2', 'admin_name_3', 'place_name'], inplace=True)
except KeyError:
    pass
file_path = country_path / '_'.join([country_code, 'geocoding.csv'])
geonames_df.to_csv(file_path, index=False)
